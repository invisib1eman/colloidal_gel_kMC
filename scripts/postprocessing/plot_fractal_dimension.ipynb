# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import json

# %%
df = pd.read_csv('../../fractal_dimension/fractal_dimension.txt', sep='\s+')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/nl/0wymk6gn3bs5t88nh2hh2n400000gn/T/ipykernel_24744/4106759930.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('../../fractal_dimension/fractal_dimension.txt', sep='\s+')

# %%
df
# Out:
#     salt  step_size  n_particles  box_length  total_time  tau_crawl  freeroll  \
# 0    0.9        0.1         8000       100.0       300.0        1.0      True
# 1    0.9        0.1         8000       100.0       300.0        1.0      True
# 2    0.9        0.1         8000       100.0       300.0        1.0      True
# 3    0.9        0.1         8000       100.0       300.0        1.0      True
# 4    0.9        0.1         8000       100.0       300.0        1.0      True
# ..   ...        ...          ...         ...         ...        ...       ...
# 95  80.0        0.1         8000       100.0       300.0      100.0      True
# 96  80.0        0.1         8000       100.0       300.0      100.0      True
# 97  80.0        0.1         8000       100.0       300.0      100.0      True
# 98  80.0        0.1         8000       100.0       300.0      100.0      True
# 99  80.0        0.1         8000       100.0       300.0      100.0      True
#
#     start_index  end_index    Df
# ...

# %%
# Filter data for tau_crawl = 1
df_tau1 = df[df['tau_crawl'] == 1.0]

# Create a figure
plt.figure(figsize=(10, 6))

# Get unique salt concentrations
salt_values = df_tau1['salt'].unique()

# Plot Df versus start_index for each salt concentration
for salt in salt_values:
    salt_data = df_tau1[df_tau1['salt'] == salt]
    plt.plot(salt_data['start_index'], salt_data['Df'], marker='o', linestyle='-', label=f'Salt = {salt}')

plt.xlabel('Start Index')
plt.ylabel('Fractal Dimension (Df)')
plt.title('Fractal Dimension vs Start Index for Different Salt Concentrations (τ_crawl = 1)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Filter data for tau_crawl = 1
df_tau100 = df[df['tau_crawl'] == 100]

# Create a figure
plt.figure(figsize=(10, 6))

# Get unique salt concentrations
salt_values = df_tau100['salt'].unique()

# Plot Df versus start_index for each salt concentration
for salt in salt_values:
    salt_data = df_tau100[df_tau100['salt'] == salt]
    plt.plot(salt_data['start_index'], salt_data['Df'], marker='o', linestyle='-', label=f'Salt = {salt}')

plt.xlabel('Start Index')
plt.ylabel('Fractal Dimension (Df)')
plt.title('Fractal Dimension vs Start Index for Different Salt Concentrations (τ_crawl = 100)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
